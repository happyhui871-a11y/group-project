# %% [markdown]
# <a href="https://colab.research.google.com/github/adger742-spec/group-project/blob/main/sklearn_vs_arima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Define the historical data
data = {
    "Date": [
        "9/1/2024", "10/1/2024", "11/1/2024", "12/1/2024", "15/1/2024", "16/1/2024",
        "17/1/2024", "18/1/2024", "19/1/2024", "22/1/2024", "23/1/2024", "24/1/2024",
        "25/1/2024", "26/1/2024"
    ],
    "Open": [
        86.800003, 86.5, 85.449997, 86.199997, 85.449997, 85.599998, 83.199997,
        82.25, 83.5, 82.5, 79.599998, 81, 82.949997, 82.800003
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the Date column to datetime
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)

# Sort the DataFrame by date in ascending order
df = df.sort_values(by="Date", ascending=True)

# Reset the index after sorting
df = df.reset_index(drop=True)

# Create a new DataFrame for prediction
prediction_data = pd.DataFrame({
    "Date": pd.to_datetime(["27/1/2024", "28/1/2024", "29/1/2024"], dayfirst=True)
})

# Fit a linear regression model
model = LinearRegression()
model.fit(df.index.values.reshape(-1, 1), df["Open"])

# Predict the open values for the next 3 days
prediction_data["Open"] = model.predict(prediction_data.index.values.reshape(-1, 1))

# Print the predicted open values
print(prediction_data)
# Out:
#         Date       Open
# 0 2024-01-27  86.689999
# 1 2024-01-28  86.251977
# 2 2024-01-29  85.813955

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA

# Define the historical data
data = {
    "Date": [
        "9/1/2024", "10/1/2024", "11/1/2024", "12/1/2024", "15/1/2024", "16/1/2024",
        "17/1/2024", "18/1/2024", "19/1/2024", "22/1/2024", "23/1/2024", "24/1/2024",
        "25/1/2024", "26/1/2024"
    ],
    "Open": [
        86.800003, 86.5, 85.449997, 86.199997, 85.449997, 85.599998, 83.199997,
        82.25, 83.5, 82.5, 79.599998, 81, 82.949997, 82.800003
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the Date column to datetime
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)

# Set the Date column as the index
df.set_index("Date", inplace=True)

# Convert the data type of the Open column to float
df["Open"] = df["Open"].astype(float)

# Fit the ARIMA model
model = ARIMA(df["Open"], order=(1, 0, 0))
model_fit = model.fit()

# Predict the open values for the next 3 days
forecast = model_fit.forecast(steps=3)
next_dates = pd.date_range(start=df.index[-1], periods=4, closed='right')[1:]
prediction_data = pd.DataFrame({
    "Date": next_dates,
    "Open": forecast[0]
})

# Print the predicted open values
print(prediction_data)
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_19018/2647459117.py in <cell line: 0>()
#      34 # Predict the open values for the next 3 days
#      35 forecast = model_fit.forecast(steps=3)
# ---> 36 next_dates = pd.date_range(start=df.index[-1], periods=4, closed='right')[1:]
#      37 prediction_data = pd.DataFrame({
#      38     "Date": next_dates,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, inclusive, unit, **kwargs)
#    1006         freq = "D"
#    1007
# -> 1008     dtarr = DatetimeArray._generate_range(
#    1009         start=start,
#    1010         end=end,
#
# TypeError: DatetimeArray._generate_range() got an unexpected keyword argument 'closed'

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Define the historical data
data = {
    "Date": [
        "9/1/2024", "10/1/2024", "11/1/2024", "12/1/2024", "15/1/2024", "16/1/2024",
        "17/1/2024", "18/1/2024", "19/1/2024", "22/1/2024", "23/1/2024", "24/1/2024",
        "25/1/2024", "26/1/2024"
    ],
    "Open": [
        86.800003, 86.5, 85.449997, 86.199997, 85.449997, 85.599998, 83.199997,
        82.25, 83.5, 82.5, 79.599998, 81, 82.949997, 82.800003
    ],
    "Volume": [
        828137, 1198206, 726415, 1743907, 0, 3421388, 2046396, 2432394,
        1384820, 2201636, 1429331, 2226788, 1429685, 1187765
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the Date column to datetime
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)

# Sort the DataFrame by date in ascending order
df = df.sort_values(by="Date", ascending=True)

# Reset the index after sorting
df = df.reset_index(drop=True)

# Split the data into training and testing sets
train_size = int(len(df) * 0.8)
train_data = df[:train_size]
test_data = df[train_size:]

# Fit the linear regression model for Volume
model_volume = LinearRegression()
model_volume.fit(train_data[["Open"]], train_data["Volume"])

# Predict the next Open value
next_open = df["Open"].iloc[-1]
next_volume = model_volume.predict([[next_open]])

# Print the predicted next Volume value
print("Predicted Volume:", next_volume[0])

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Define the historical data
data = {
    "Date": [
        "9/1/2024", "10/1/2024", "11/1/2024", "12/1/2024", "15/1/2024", "16/1/2024",
        "17/1/2024", "18/1/2024", "19/1/2024", "22/1/2024", "23/1/2024", "24/1/2024",
        "25/1/2024", "26/1/2024"
    ],
    "Open": [
        86.800003, 86.5, 85.449997, 86.199997, 85.449997, 85.599998, 83.199997,
        82.25, 83.5, 82.5, 79.599998, 81, 82.949997, 82.800003
    ],
    "Volume": [
        828137, 1198206, 726415, 1743907, 0, 3421388, 2046396, 2432394,
        1384820, 2201636, 1429331, 2226788, 1429685, 1187765
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the Date column to datetime
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)

# Sort the DataFrame by date in ascending order
df = df.sort_values(by="Date", ascending=True)

# Reset the index after sorting
df = df.reset_index(drop=True)

# Split the data into training and testing sets
train_size = int(len(df) * 0.8)
train_data = df[:train_size]
test_data = df[train_size:]

# Fit the linear regression model for Volume
model_volume = LinearRegression()
model_volume.fit(train_data[["Open"]], train_data["Volume"])

# Predict the next Open and Volume values
next_open = df["Open"].iloc[-1]
next_volume = model_volume.predict([[next_open]])

# Print the predicted next Open and Volume values
print("Predicted Open:", next_open)
print("Predicted Volume:", next_volume[0])
